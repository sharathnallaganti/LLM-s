# %% [markdown]
# ## Query (Q), Key (K), and Value (V)
#
# After tokenization, embedding lookup, positional encoding, and normalization, each token is represented by a dense vector that captures both its semantic meaning and positional information.
#
# At this stage, however, each token is still independent. For example, in the sentence:
#
# > **"cat sat on mat"**
#
# the token **"cat"** knows only its own representation, **"sat"** knows only its own representation, and no interaction has occurred between them. The model has not yet learned how the tokens relate to one another.
#
# For the Transformer to understand the context of a sentence, tokens must communicate with each other. They need a mechanism to determine:
#
# - Which tokens are relevant?
# - How relevant are they?
# - What information should be exchanged?
#
# A natural question arises:
#
# **Why can't the Transformer compute attention directly on the embedding matrix?**
#
# Although embeddings capture the semantic meaning of tokens, they are not designed to perform the different roles required by the attention mechanism. A single embedding cannot simultaneously represent:
#
# - What information a token is searching for.
# - What information a token contains.
# - What information a token should pass to other tokens.
#
# To solve this problem, the Transformer projects every input embedding into three different vector spaces using three learnable weight matrices.
#
# $$
# Q = XW_Q
# $$
#
# $$
# K = XW_K
# $$
#
# $$
# V = XW_V
# $$
#
# where:
#
# - **Query (Q)** represents what information a token is searching for.
# - **Key (K)** represents what information a token contains.
# - **Value (V)** represents the information that will be passed to other tokens.
#
# These three projections form the foundation of the self-attention mechanism. By comparing Query vectors with Key vectors, the Transformer determines how much attention each token should pay to every other token. The resulting attention weights are then applied to the Value vectors to produce context-aware representations of the input sequence.

# %% [markdown]
# ## Query (Q), Key (K), and Value (V)
#
# After learning tokenization, embeddings, positional encoding, and normalization, the next step is to understand how the Transformer enables tokens to interact with one another.
#
# The attention mechanism begins by projecting the input embeddings into three different vector spaces called **Query (Q)**, **Key (K)**, and **Value (V)**.
#
# ### 1. Query (Q)
#
# Study the following concepts:
#
# - What is a Query?
# - Why is it called a Query?
# - What information does it represent?
# - Matrix dimensions
# - Weight initialization
# - Mathematical formulation
#
# Formula:
#
# $$
# Q = XW_Q
# $$
#
# where:
#
# - \(X\) is the input embedding matrix.
# - \(W_Q\) is the learnable Query weight matrix.
#
# ### 2. Key (K)
#
# Study the following concepts:
#
# - What is a Key?
# - Why is it called a Key?
# - How does it interact with the Query?
# - Matrix dimensions
# - Weight initialization
# - Mathematical formulation
#
# Formula:
#
# $$
# K = XW_K
# $$
#
# where:
#
# - \(X\) is the input embedding matrix.
# - \(W_K\) is the learnable Key weight matrix.
#
# ### 3. Value (V)
#
# Study the following concepts:
#
# - What is a Value?
# - Why is it different from the Key?
# - Why don't we directly use embeddings as Values?
# - Matrix dimensions
# - Weight initialization
# - Mathematical formulation
#
# Formula:
#
# $$
# V = XW_V
# $$
#
# where:
#
# - \(X\) is the input embedding matrix.
# - \(W_V\) is the learnable Value weight matrix.
#
# ### 4. Matrix Multiplication
#
# Using the example sentence:
#
# > **"cat sat on mat"**
#
# Take the input embedding matrix:
#
# $$
# X=
# \begin{bmatrix}
# 0.3 & 0.8 & 0.1 & 0.5 \\
# 0.9 & 0.4 & 0.4 & 0.1 \\
# 0.5 & 0.2 & 0.8 & 0.3 \\
# 0.6 & 0.9 & 0.2 & 0.5
# \end{bmatrix}
# $$
#
# Manually compute:
#
# $$
# Q = XW_Q
# $$
#
# Then compute:
#
# $$
# K = XW_K
# $$
#
# Finally compute:
#
# $$
# V = XW_V
# $$
#
# This step demonstrates how the same input embeddings are transformed into three different learned representations.
#
# ### 5. Attention Score Matrix
#
# Once the Query and Key matrices are obtained, compute:
#
# $$
# QK^T
# $$
#
# This produces an attention score for every Query-Key pair.
#
# Each element represents how strongly one token attends to another.
#
# ### 6. Scaled Dot Product
#
# To stabilize the attention scores, divide by:
#
# $$
# \sqrt{d_k}
# $$
#
# Formula:
#
# $$
# \frac{QK^T}{\sqrt{d_k}}
# $$
#
# Understand why scaling is necessary before applying Softmax.
#
# ### 7. Softmax
#
# Convert the scaled attention scores into probabilities:
#
# $$
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)
# $$
#
# The resulting values indicate the attention weight assigned to each token.
#
# ### 8. Weighted Sum of Values
#
# Multiply the attention weights by the Value matrix:
#
# $$
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)V
# $$
#
# This produces a new contextual representation for every token.
#
# ### 9. Complete Scaled Dot Product Attention
#
# Finally derive and understand the complete attention equation:
#
# $$
# Attention(Q,K,V)
# =
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)V
# $$
#
# You should be able to explain the purpose of every matrix and every operation in this equation.
#
# ### 10. Multi-Head Attention
#
# After mastering single-head attention, proceed to Multi-Head Attention.
#
# Study:
#
# $$
# head_i
# =
# Attention(Q_i,K_i,V_i)
# $$
#
# Then combine all attention heads:
#
# $$
# MultiHead
# =
# Concat(head_1,\ldots,head_h)W_O
# $$
#
# Understand why multiple attention heads allow the model to capture different types of relationships simultaneously.

# %% [markdown]
# ## Query (Q)
#
# The **Query (Q)** is one of the three fundamental components of the self-attention mechanism in a Transformer. It represents the information that a token is searching for from all other tokens in the input sequence.
#
# In simple terms, a Query can be thought of as a **question** asked by a token.
#
# For example, consider the sentence:
#
# > **"The cat sat on the mat."**
#
# When processing the token **"sat"**, the Query generated for **"sat"** asks:
#
# - Who performed the action?
# - Which token is most relevant to me?
# - Which tokens should I pay attention to?
#
# The Query itself does not contain the answer. Instead, it is compared with the Key vectors of every token in the sequence to determine which tokens are most relevant.
#
# ### Why Do We Need Query?
#
# If attention were computed directly on embeddings, every token would have only one representation.
#
# However, attention requires every token to perform three different tasks:
#
# - Search for relevant information.
# - Describe the information it contains.
# - Pass useful information to other tokens.
#
# These tasks are fundamentally different.
#
# Therefore, the Transformer learns three different representations for every token:
#
# - Query (Q)
# - Key (K)
# - Value (V)
#
# The Query is responsible only for searching.
#
# ### Mathematical Formulation
#
# Suppose the input embedding matrix after positional encoding is:
#
# $$
# X
# =
# \begin{bmatrix}
# 0.3 & 0.8 & 0.1 & 0.5 \\
# 0.9 & 0.4 & 0.4 & 0.1 \\
# 0.5 & 0.2 & 0.8 & 0.3 \\
# 0.6 & 0.9 & 0.2 & 0.5
# \end{bmatrix}
# $$
#
# The Query matrix is computed using a learnable weight matrix:
#
# $$
# Q=XW_Q
# $$
#
# where:
#
# - \(X\) is the input embedding matrix.
# - \(W_Q\) is the Query weight matrix.
# - \(Q\) is the Query matrix.
#
# ### Dimensions
#
# Suppose:
#
# - Sequence Length = 4
# - Embedding Dimension = 4
#
# Then,
#
# $$
# X
# \in
# \mathbb{R}^{4\times4}
# $$
#
# If
#
# $$
# W_Q
# \in
# \mathbb{R}^{4\times2}
# $$
#
# then
#
# $$
# Q
# =
# XW_Q
# \in
# \mathbb{R}^{4\times2}
# $$
#
# Each row of \(Q\) corresponds to the Query vector of one token.
#
# ### How is \(W_Q\) Initialized?
#
# The Query weight matrix is initialized randomly before training.
#
# Typical initialization methods include:
#
# - Xavier Initialization
# - Kaiming Initialization
# - Normal Distribution
#
# Example:
#
# $$
# W_Q=
# \begin{bmatrix}
# 0.12 & -0.08\\
# 0.04 & 0.17\\
# -0.09 & 0.11\\
# 0.21 & -0.03
# \end{bmatrix}
# $$
#
# Initially, these values have no semantic meaning.
#
# During training, backpropagation updates \(W_Q\) so that the Query vectors learn how to search for relevant information.
#
# ### Example Computation
#
# Suppose
#
# $$
# W_Q=
# \begin{bmatrix}
# 1 & 0\\
# 0 & 1\\
# 1 & 0\\
# 0 & 1
# \end{bmatrix}
# $$
#
# Then,
#
# $$
# Q=XW_Q
# $$
#
# becomes
#
# $$
# Q=
# \begin{bmatrix}
# 0.4 & 1.3\\
# 1.3 & 0.5\\
# 1.3 & 0.5\\
# 0.8 & 1.4
# \end{bmatrix}
# $$
#
# Each row now represents the Query vector for one token.
#
# ### Interpretation
#
# For the sentence:
#
# > **"cat sat on mat"**
#
# The Query vector for:
#
# **cat**
#
# asks:
#
# > Which tokens are important for understanding "cat"?
#
# The Query vector for:
#
# **sat**
#
# asks:
#
# > Which token tells me who performed the action?
#
# The Query vector for:
#
# **mat**
#
# asks:
#
# > Which tokens describe my relationship with the sentence?
#
# Each Query is different because each token has a different role in the sentence.
#
# ### What Happens Next?
#
# The Query vectors are compared with every Key vector using the dot product.
#
# Mathematically,
#
# $$
# Score
# =
# QK^T
# $$
#
# Each element of this matrix represents how strongly a Query matches a Key.
#
# These scores are later converted into probabilities using the Softmax function.
#
# ### Important Points to Remember
#
# - Every token has exactly one Query vector.
# - Query vectors are learned during training.
# - Query vectors determine what information a token is searching for.
# - Query vectors are computed using a linear transformation of the input embeddings.
# - Query vectors are compared with Key vectors to compute attention scores.
# - Query vectors never directly interact with Value vectors.
# - The Query matrix has the same number of rows as the number of input tokens.
# - Query vectors are recomputed at every Transformer layer.
# - Different Transformer layers learn different Query representations.
# - Without Query vectors, the attention mechanism cannot determine which information each token should retrieve.
#
# ### Interview Question
#
# **What is the purpose of the Query vector in a Transformer?**
#
# **Answer:**
#
# The Query vector represents what information a token is searching for. It is obtained by projecting the input embeddings using a learnable weight matrix \(W_Q\). During self-attention, each Query vector is compared with every Key vector to compute attention scores, which determine how much attention the token should pay to other tokens in the sequence.

# %% [markdown]
# ## Key (K)
#
# The **Key (K)** It represents the information that each token contains and makes available to other tokens during the attention process.
#
# In simple terms, a Key can be thought of as an **identifier** or **description** of a token.
#
# For example, consider the sentence:
#
# > **"The cat sat on the mat."**
#
# When processing the token **"sat"**, the Transformer compares its Query vector against the Key vectors of all tokens:
#
# - Key(cat)
# - Key(sat)
# - Key(on)
# - Key(mat)
#
# The Key vectors help determine which tokens contain the information that the Query is searching for.
#
# ### Why Do We Need Key?
#
# The Query vector asks a question, but another mechanism is needed to determine which tokens can answer that question.
#
# The Key vector serves this purpose.
#
# Each Key describes the information contained in its corresponding token.
#
# During self-attention, every Query is compared with every Key to compute attention scores.
#
# Without Key vectors, the model would have no mechanism to determine which tokens are relevant to the current token.
#
# ### Mathematical Formulation
#
# Suppose the input embedding matrix after positional encoding is:
#
# $$
# X
# =
# \begin{bmatrix}
# 0.3 & 0.8 & 0.1 & 0.5 \\
# 0.9 & 0.4 & 0.4 & 0.1 \\
# 0.5 & 0.2 & 0.8 & 0.3 \\
# 0.6 & 0.9 & 0.2 & 0.5
# \end{bmatrix}
# $$
#
# The Key matrix is computed using a learnable weight matrix:
#
# $$
# K=XW_K
# $$
#
# where:
#
# - \(X\) is the input embedding matrix.
# - \(W_K\) is the Key weight matrix.
# - \(K\) is the Key matrix.
#
# ### Dimensions
#
# Suppose:
#
# - Sequence Length = 4
# - Embedding Dimension = 4
#
# Then,
#
# $$
# X
# \in
# \mathbb{R}^{4\times4}
# $$
#
# If
#
# $$
# W_K
# \in
# \mathbb{R}^{4\times2}
# $$
#
# then
#
# $$
# K
# =
# XW_K
# \in
# \mathbb{R}^{4\times2}
# $$
#
# Each row of \(K\) corresponds to the Key vector of one token.
#
# ### How is \(W_K\) Initialized?
#
# The Key weight matrix is initialized randomly before training.
#
# Typical initialization methods include:
#
# - Xavier Initialization
# - Kaiming Initialization
# - Normal Distribution
#
# Example:
#
# $$
# W_K=
# \begin{bmatrix}
# 0.15 & -0.04\\
# -0.02 & 0.18\\
# 0.11 & 0.06\\
# 0.08 & -0.09
# \end{bmatrix}
# $$
#
# Initially, these values have no semantic meaning.
#
# During training, backpropagation updates \(W_K\) so that the Key vectors learn how to represent the information contained in each token.
#
# ### Example Computation
#
# Suppose
#
# $$
# W_K=
# \begin{bmatrix}
# 1 & 1\\
# 0 & 1\\
# 1 & 0\\
# 0 & 1
# \end{bmatrix}
# $$
#
# Then,
#
# $$
# K=XW_K
# $$
#
# becomes
#
# $$
# K=
# \begin{bmatrix}
# 0.4 & 1.7\\
# 1.3 & 1.8\\
# 1.3 & 1.0\\
# 0.8 & 2.3
# \end{bmatrix}
# $$
#
# Each row now represents the Key vector for one token.
#
# ### Interpretation
#
# For the sentence:
#
# > **"cat sat on mat"**
#
# The Key vector for:
#
# **cat**
#
# describes the information contained in the token **"cat"**.
#
# The Key vector for:
#
# **sat**
#
# describes the information contained in the token **"sat"**.
#
# The Key vector for:
#
# **mat**
#
# describes the information contained in the token **"mat"**.
#
# When another token generates a Query, these Key vectors are compared against that Query to determine how relevant each token is.
#
# ### What Happens Next?
#
# The Key vectors are compared with every Query vector using the dot product.
#
# Mathematically,
#
# $$
# Score
# =
# QK^T
# $$
#
# Each element of this matrix represents how well a Query matches a Key.
#
# A higher score indicates that the corresponding token is more relevant to the current Query.
#
# These scores are later scaled and passed through the Softmax function to obtain attention weights.
#
# ### Important Points to Remember
#
# - Every token has exactly one Key vector.
# - Key vectors are learned during training.
# - Key vectors represent the information contained in each token.
# - Key vectors are computed using a linear transformation of the input embeddings.
# - Key vectors are compared with Query vectors to compute attention scores.
# - Key vectors do not directly interact with Value vectors.
# - The Key matrix has the same number of rows as the number of input tokens.
# - Key vectors are recomputed at every Transformer layer.
# - Different Transformer layers learn different Key representations.
# - Without Key vectors, the attention mechanism cannot determine which tokens contain relevant information.
#
# ### Interview Question
#
# **What is the purpose of the Key vector in a Transformer?**
#
# **Answer:**
#
# The Key vector represents the information contained in each token. It is obtained by projecting the input embeddings using a learnable weight matrix \(W_K\). During self-attention, every Query vector is compared with every Key vector to compute attention scores, which determine how relevant each token is to the current token.

# %% [markdown]
# ## Full Self-Attention Computation Example
#
# We will use the sentence:
#
# > **"Alice gave Bob a book"**
#
# The complete computation flow is:
#
# $$
# \text{Text}
# \rightarrow
# \text{Tokenization}
# \rightarrow
# \text{Token IDs}
# \rightarrow
# \text{Embedding Lookup}
# \rightarrow
# \text{Positional Encoding}
# \rightarrow
# X
# \rightarrow
# Q,K,V
# \rightarrow
# QK^T
# \rightarrow
# \frac{QK^T}{\sqrt{d_k}}
# \rightarrow
# Softmax
# \rightarrow
# Softmax\left(\frac{QK^T}{\sqrt{d_k}}\right)V
# $$
#
# ## Step-by-Step Process
#
# ### 1. Tokenization
#
# $$
# \text{"Alice gave Bob a book"}
# \rightarrow
# [\text{Alice}, \text{gave}, \text{Bob}, \text{a}, \text{book}]
# $$
#
# ### 2. Token IDs
#
# $$
# [\text{Alice}, \text{gave}, \text{Bob}, \text{a}, \text{book}]
# \rightarrow
# [15,42,89,7,102]
# $$
#
# ### 3. Embedding Lookup
#
# Each token ID is mapped to an embedding vector.
#
# ### 4. Positional Encoding
#
# Position information is added to each token embedding.
#
# ### 5. Input Matrix
#
# The result becomes the input matrix:
#
# $$
# X
# $$
#
# ### 6. Define Weight Matrices
#
# The Transformer defines three learnable matrices:
#
# $$
# W_Q
# $$
#
# $$
# W_K
# $$
#
# $$
# W_V
# $$
#
# ### 7. Compute Query Matrix
#
# $$
# Q = XW_Q
# $$
#
# ### 8. Compute Key Matrix
#
# $$
# K = XW_K
# $$
#
# ### 9. Compute Value Matrix
#
# $$
# V = XW_V
# $$
#
# ### 10. Compute Attention Scores
#
# $$
# QK^T
# $$
#
# ### 11. Scale Attention Scores
#
# $$
# \frac{QK^T}{\sqrt{d_k}}
# $$
#
# ### 12. Apply Softmax Row by Row
#
# $$
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)
# $$
#
# ### 13. Multiply by Value Matrix
#
# $$
# Attention(Q,K,V)
# =
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)V
# $$
#
# ### 14. Contextual Embeddings
#
# The output gives contextual embeddings for every token:
#
# $$
# Alice,\ gave,\ Bob,\ a,\ book
# $$
#
# ### 15. What Changed?
#
# After attention:
#
# - **Alice** contains information about her role as the giver.
# - **gave** captures the relationship between Alice, Bob, and book.
# - **Bob** contains information about being the receiver.
# - **a** contributes little semantic meaning but supports grammar.
# - **book** contains information about being the object being given.

# %% [markdown]
# ## Step 1: Tokenization
#
# Sentence:
#
# > Alice gave Bob a book
#
# Tokens:
#
# $$
# [\text{Alice},\ \text{gave},\ \text{Bob},\ \text{a},\ \text{book}]
# $$
#
# ---
#
# ## Step 2: Token IDs
#
# Assume our vocabulary assigns:
#
# $$
# [15,\ 42,\ 89,\ 7,\ 102]
# $$
#
# ---
#
# ## Step 3: Embedding Lookup
#
# Suppose the embedding matrix returns:
#
# $$
# E=
# \begin{bmatrix}
# 0.2 & 0.8 & 0.1 & 0.4\\
# 0.7 & 0.2 & 0.6 & 0.1\\
# 0.5 & 0.9 & 0.3 & 0.8\\
# 0.1 & 0.3 & 0.2 & 0.6\\
# 0.8 & 0.4 & 0.7 & 0.2
# \end{bmatrix}
# $$
#
# Rows correspond to:
#
# Alice
#
# gave
#
# Bob
#
# a
#
# book
#
# ---
#
# ## Step 4: Positional Encoding
#
# Suppose
#
# $$
# P=
# \begin{bmatrix}
# 0.10 & 0.00 & 0.00 & 0.00\\
# 0.00 & 0.10 & 0.00 & 0.00\\
# 0.00 & 0.00 & 0.10 & 0.00\\
# 0.00 & 0.00 & 0.00 & 0.10\\
# 0.10 & 0.10 & 0.10 & 0.10
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 5: Input Matrix
#
# The Transformer computes
#
# $$
# X=E+P
# $$
#
# Result:
#
# $$
# X=
# \begin{bmatrix}
# 0.30 & 0.80 & 0.10 & 0.40\\
# 0.70 & 0.30 & 0.60 & 0.10\\
# 0.50 & 0.90 & 0.40 & 0.80\\
# 0.10 & 0.30 & 0.20 & 0.70\\
# 0.90 & 0.50 & 0.80 & 0.30
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 6: Initialize Query Weight Matrix
#
# $$
# W_Q=
# \begin{bmatrix}
# 0.2 & 0.5\\
# 0.1 & 0.3\\
# 0.4 & 0.2\\
# 0.6 & 0.1
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 7: Initialize Key Weight Matrix
#
# $$
# W_K=
# \begin{bmatrix}
# 0.3 & 0.2\\
# 0.2 & 0.4\\
# 0.5 & 0.1\\
# 0.1 & 0.6
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 8: Initialize Value Weight Matrix
#
# $$
# W_V=
# \begin{bmatrix}
# 0.6 & 0.1\\
# 0.2 & 0.5\\
# 0.3 & 0.4\\
# 0.4 & 0.2
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 9: Compute Query Matrix
#
# $$
# Q=XW_Q
# $$
#
# Result:
#
# $$
# Q=
# \begin{bmatrix}
# 0.43 & 0.43\\
# 0.48 & 0.52\\
# 0.86 & 0.64\\
# 0.56 & 0.24\\
# 0.84 & 0.80
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 10: Compute Key Matrix
#
# $$
# K=XW_K
# $$
#
# Result:
#
# $$
# K=
# \begin{bmatrix}
# 0.34 & 0.62\\
# 0.58 & 0.37\\
# 0.64 & 0.93\\
# 0.24 & 0.57\\
# 0.84 & 0.67
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 11: Compute Value Matrix
#
# $$
# V=XW_V
# $$
#
# Result:
#
# $$
# V=
# \begin{bmatrix}
# 0.55 & 0.53\\
# 0.70 & 0.44\\
# 0.93 & 0.83\\
# 0.43 & 0.39\\
# 1.06 & 0.82
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 12: Compute Attention Scores
#
# $$
# QK^T
# $$
#
# Result:
#
# $$
# QK^T=
# \begin{bmatrix}
# 0.41 & 0.41 & 0.67 & 0.35 & 0.65\\
# 0.49 & 0.47 & 0.79 & 0.41 & 0.75\\
# 0.69 & 0.74 & 1.14 & 0.57 & 1.15\\
# 0.34 & 0.41 & 0.58 & 0.27 & 0.63\\
# 0.78 & 0.78 & 1.29 & 0.66 & 1.24
# \end{bmatrix}
# $$
#
# ---
#
# ## Step 13: Scale Scores
#
# Since
#
# $$
# d_k=2
# $$
#
# $$
# \sqrt{d_k}=1.414
# $$
#
# Compute
#
# $$
# \frac{QK^T}{1.414}
# $$
#
# Result:
#
# $$
# \begin{bmatrix}
# 0.29 & 0.29 & 0.47 & 0.25 & 0.46\\
# 0.35 & 0.33 & 0.56 & 0.29 & 0.53\\
# 0.49 & 0.52 & 0.81 & 0.40 & 0.81\\
# 0.24 & 0.29 & 0.41 & 0.19 & 0.45\\
# 0.55 & 0.55 & 0.91 & 0.47 & 0.88
# \end{bmatrix}
# $$

# %% [markdown]
# ## Step 14: Apply Softmax Row by Row
#
# The scaled attention score matrix is:
#
# $$
# S=
# \begin{bmatrix}
# 0.29 & 0.29 & 0.47 & 0.25 & 0.46\\
# 0.35 & 0.33 & 0.56 & 0.29 & 0.53\\
# 0.49 & 0.52 & 0.81 & 0.40 & 0.81\\
# 0.24 & 0.29 & 0.41 & 0.19 & 0.45\\
# 0.55 & 0.55 & 0.91 & 0.47 & 0.88
# \end{bmatrix}
# $$
#
# Apply Softmax to each row:
#
# $$
# A=
# Softmax(S)
# $$
#
# Result:
#
# $$
# A=
# \begin{bmatrix}
# 0.187 & 0.187 & 0.224 & 0.180 & 0.222\\
# 0.187 & 0.183 & 0.230 & 0.176 & 0.224\\
# 0.175 & 0.181 & 0.242 & 0.160 & 0.242\\
# 0.184 & 0.194 & 0.219 & 0.175 & 0.228\\
# 0.174 & 0.174 & 0.249 & 0.161 & 0.242
# \end{bmatrix}
# $$
#
# This matrix is called the **attention weight matrix**.
#
# Each row sums to 1.
#
# Each row shows how much attention one token gives to all tokens.
#
# ## Step 15: Multiply Attention Weights by Value Matrix
#
# The Value matrix is:
#
# $$
# V=
# \begin{bmatrix}
# 0.55 & 0.53\\
# 0.70 & 0.44\\
# 0.93 & 0.83\\
# 0.43 & 0.39\\
# 1.06 & 0.82
# \end{bmatrix}
# $$
#
# Now compute:
#
# $$
# Output = AV
# $$
#
# or:
#
# $$
# Output =
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)V
# $$
#
# Result:
#
# $$
# Output=
# \begin{bmatrix}
# 0.755 & 0.620\\
# 0.758 & 0.623\\
# 0.773 & 0.634\\
# 0.757 & 0.620\\
# 0.775 & 0.637
# \end{bmatrix}
# $$
#
# ## Step 16: Final Contextual Embeddings
#
# Each row of the output matrix is now a contextual embedding.
#
# $$
# \begin{bmatrix}
# Alice\\
# gave\\
# Bob\\
# a\\
# book
# \end{bmatrix}
# \rightarrow
# \begin{bmatrix}
# 0.755 & 0.620\\
# 0.758 & 0.623\\
# 0.773 & 0.634\\
# 0.757 & 0.620\\
# 0.775 & 0.637
# \end{bmatrix}
# $$
#
# ## Step 17: What Changed for Each Token?
#
# ### Alice
#
# Before attention, **Alice** only had its own embedding.
#
# After attention, Alice's new vector contains information from:
#
# - Alice
# - gave
# - Bob
# - a
# - book
#
# ### gave
#
# The token **gave** now contains contextual information about the giver, receiver, and object.
#
# It is no longer just the word **gave**.
#
# It now represents the action in the full sentence.
#
# ### Bob
#
# The token **Bob** now receives information from **Alice**, **gave**, and **book**.
#
# This helps the model understand Bob's role as the receiver.
#
# ### a
#
# The token **a** has weak semantic meaning, but it still participates in attention.
#
# It mainly supports grammatical structure.
#
# ### book
#
# The token **book** now contains information about being the object involved in the action **gave**.
#
# ## Step 18: Complete Self-Attention Equation
#
# The complete computation is:
#
# $$
# Attention(Q,K,V)
# =
# Softmax
# \left(
# \frac{QK^T}{\sqrt{d_k}}
# \right)V
# $$
#
# For this example:
#
# $$
# Attention(Q,K,V)
# =
# \begin{bmatrix}
# 0.755 & 0.620\\
# 0.758 & 0.623\\
# 0.773 & 0.634\\
# 0.757 & 0.620\\
# 0.775 & 0.637
# \end{bmatrix}
# $$
#
# This is the final output of one single-head self-attention layer.
